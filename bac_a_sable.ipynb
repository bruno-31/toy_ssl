# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_biclusters
from sklearn.model_selection import train_test_split
import glob

# %%
def plot_dics(l):
    plt.figure(figsize=(40,20))
    plt.subplot(121)
    names=[]
#     for var in ['test']:
    for var in ['ema']:
        for d in l:
            x=d.item().get(var)
            plt.plot(x)
            names.append(var + '_' + d.item().get('name'))
    plt.legend(names, prop={'size': 14})
    plt.subplot(122)
    names=[]
    for var in ['loss','mani']:
        for d in l:
            x=d.item().get(var)
            plt.plot(x)
            names.append(var + '_' + d.item().get('name'))
            plt.legend(names, prop={'size': 14})

# %%
plot_dics([np.load(path) for path in glob.glob('*.npy')])
fig = plt.gcf()

fig.savefig('./trajectories.png', dpi=200)

# %%
l= glob.glob('*.npy')
l
# Out:
# ['vanilla_ema4.npy',
#  'gamma0.05_epsilon25_eta2_ema.npy',
#  'gamma0.03_epsilon20_ema.npy',
#  'vanilla_ema2.npy',
#  'gamma0.1_epsilon25_eta2_ema.npy',
#  'vanilla_ema.npy',
#  'gamma0.04_epsilon25_eta2_ema.npy',
#  'vanilla_ema3.npy',
#  'gamma0.07_epsilon25_eta2_ema.npy']

# %%
l=[l[i] for i in ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0d5b63aafb72> in <module>()
# ----> 1 l=l[[0,1,3]]
#
# TypeError: list indices must be integers or slices, not list
